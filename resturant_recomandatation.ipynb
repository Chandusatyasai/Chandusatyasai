# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandusatyasai/Chandusatyasai/blob/cognifyz/resturant_recomandatation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas scikit-learn

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df['combined_features'] = df['Cuisine'] + ' ' + df['Price_Range'] + ' ' + df['Location']
df.head()
# Out:
#   Restaurant_Name   Cuisine  Location Price_Range  Rating  \
# 0    Pizza Palace   Italian  Downtown          $$     4.5
# 1     Sushi World  Japanese  Downtown         $$$     4.7
# 2       Taco Town   Mexican    Uptown          $$     4.2
# 3    Burger Joint  American    Uptown           $     3.8
# 4     Pasta Place   Italian  Downtown         $$$     4.6
#
#        combined_features
# 0    Italian $$ Downtown
# 1  Japanese $$$ Downtown
# 2      Mexican $$ Uptown
# 3      American $ Uptown
# 4   Italian $$$ Downtown

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['combined_features'])
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
cosine_sim
# Out:
# array([[1.        , 0.35541083, 0.        , 0.        , 1.        ],
#        [0.35541083, 1.        , 0.        , 0.        , 0.35541083],
#        [0.        , 0.        , 1.        , 0.39427569, 0.        ],
#        [0.        , 0.        , 0.39427569, 1.        , 0.        ],
#        [1.        , 0.35541083, 0.        , 0.        , 1.        ]])

# %%
def recommend_restaurants(preferred_cuisine, price_range, location=None):
    input_str = f"{preferred_cuisine} {price_range} {location if location else ''}"

    input_vec = tfidf.transform([input_str])


    similarity_scores = cosine_similarity(input_vec, tfidf_matrix).flatten()

    top_indices = similarity_scores.argsort()[-5:][::-1]

    return df.iloc[top_indices][['Restaurant_Name', 'Cuisine', 'Price_Range', 'Location']]
recommendations = recommend_restaurants(preferred_cuisine='Italian', price_range='$$', location='Downtown')
recommendations
# Out:
#   Restaurant_Name   Cuisine Price_Range  Location
# 4     Pasta Place   Italian         $$$  Downtown
# 0    Pizza Palace   Italian          $$  Downtown
# 1     Sushi World  Japanese         $$$  Downtown
# 2       Taco Town   Mexican          $$    Uptown
# 3    Burger Joint  American           $    Uptown

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e213a21e-54e0-4381-b18b-4b3e0c8819fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e213a21e-54e0-4381-b18b-4b3e0c8819fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
recommend_restaurants(preferred_cuisine='Mexican', price_range='100000000', location='Uptown')
# Out:
#   Restaurant_Name   Cuisine Price_Range  Location
# 2       Taco Town   Mexican          $$    Uptown
# 3    Burger Joint  American           $    Uptown
# 4     Pasta Place   Italian         $$$  Downtown
# 1     Sushi World  Japanese         $$$  Downtown
# 0    Pizza Palace   Italian          $$  Downtown
